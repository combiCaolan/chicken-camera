# %%
# !pip install opencv-python
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("REALISTIC-PHOTO.png")

# %%
# load the image and show it
image = cv2.imread("REALISTIC-PHOTO.png")
cv2.imshow("Original", image)
# grab the dimensions of the image and calculate the center of the
# image
(h, w) = image.shape[:2]
(cX, cY) = (w // 2, h // 2)
# rotate our image by 45 degrees around the center of the image
M = cv2.getRotationMatrix2D((cX, cY), -20, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
cv2.imshow("Rotated by 45 Degrees", rotated)
# rotate our image by -90 degrees around the image
# M = cv2.getRotationMatrix2D((cX, cY), -90, 1.0)
# rotated = cv2.warpAffine(image, M, (w, h))
# cv2.imshow("Rotated by -90 Degrees", rotated)

plt.imshow(rotated)
plt.title('my rotated image')
plt.show()


cropped_image = rotated[0:560, 0:930]
 
# Display cropped image
# cv2.imshow("cropped", cropped_image)

plt.imshow(img)
plt.title('my picture')
plt.show()

plt.imshow(cropped_image)
plt.title('my picture')
plt.show()

# %%
# Cropping an image
cropped_image = img[0:480, 0:930]
 
# Display cropped image
# cv2.imshow("cropped", cropped_image)

plt.imshow(img)
plt.title('my picture')
plt.show()

plt.imshow(cropped_image)
plt.title('my picture')
plt.show()

# Save the cropped image
# cv2.imwrite("Cropped Image.jpg", cropped_image)
 
# plt.imshow(gray)
# plt.title('my picture')
# plt.show()

# plt.imshow(img)
# plt.title('my picture')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 18
#      13 plt.show()
#      15 # Save the cropped image
#      16 # cv2.imwrite("Cropped Image.jpg", cropped_image)
# ---> 18 plt.imshow(gray)
#      19 plt.title('my picture')
#      20 plt.show()
#
# NameError: name 'gray' is not defined

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def process(img):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_canny = cv2.Canny(img_gray, 12, 54)
    kernel = np.ones((3, 3))
    img_dilate = cv2.dilate(img_canny, kernel, iterations=10)
    img_erode = cv2.erode(img_dilate, kernel, iterations=8)
    return img_erode

img = cv2.imread("image.webp")
contours, _ = cv2.findContours(process(img), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
plt.imshow(img)
plt.title('my picture')
plt.show()

# cv2.imshow("Image", img)
# cv2.waitKey(0)

# %%
import cv2
import numpy as np
 
#The line below is necessary to show Matplotlib's plots inside a Jupyter Notebook
# %matplotlib inline
 
from matplotlib import pyplot as plt
 
#Use this helper function if you are working in Jupyter Lab
#If not, then directly use cv2.imshow(<window name>, )
 
def showimage(myimage):
    if (myimage.ndim>2):  #This only applies to RGB or RGBA images (e.g. not to Black and White images)
        myimage = myimage[:,:,::-1] #OpenCV follows BGR order, while matplotlib likely follows RGB order
         
    fig, ax = plt.subplots(figsize=[10,10])
    ax.imshow(myimage, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()
showimage('chickens-.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 20
#      18     plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#      19     plt.show()
# ---> 20 showimage('chickens-.jpg')
#
# Cell In[7], line 13, in showimage(myimage)
#      12 def showimage(myimage):
# ---> 13     if (myimage.ndim>2):  #This only applies to RGB or RGBA images (e.g. not to Black and White images)
#      14         myimage = myimage[:,:,::-1] #OpenCV follows BGR order, while matplotlib likely follows RGB order
#      16     fig, ax = plt.subplots(figsize=[10,10])
#
# AttributeError: 'str' object has no attribute 'ndim'
